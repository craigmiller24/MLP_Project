# %% [markdown]
# ### Benchmark Models

# %%
# import necessary modules
import pandas as pd
import random
import torch

from DataPreprocessing.preprocessing_function import preprocess_data
from benchmark_models import train_lstm, train_random_forest, train_rf_then_lstm
from cross_validation import crossvalidation_training, metric_avgs

# %%
# Set a fixed random seed for reproducibility
SEED = 50
random.seed(SEED)
torch.manual_seed(SEED)

# %% [markdown]
# ### JFK Models

# %%
# import dataset
merged_jfk_df = pd.read_csv('data/complete/JFK_final_df.csv')

# %%
# preprocessing
X_train_torch_jfk, X_test_torch_jfk, Y_train_torch_jfk, Y_test_torch_jfk, feature_names_jfk = preprocess_data(merged_jfk_df)

# %%
jfk_RF_model, jfk_metrics_RF = train_random_forest(X_train_torch_jfk, X_test_torch_jfk, Y_train_torch_jfk, Y_test_torch_jfk, feature_names_jfk)

# %%
JFK_LSTM_model, JFK_metrics_LSTM = train_lstm(X_train_torch_jfk, X_test_torch_jfk, Y_train_torch_jfk, Y_test_torch_jfk)

# %%
JFK_RFLSTM_model, JFK_metrics_RFLSTM = train_rf_then_lstm(X_train_torch_jfk, X_test_torch_jfk, Y_train_torch_jfk, Y_test_torch_jfk, feature_names_jfk)

# %% [markdown]
# ### Miami Models

# %%
# import dataset
merged_mia_df = pd.read_csv('data/complete/MIA_final_df.csv')

# %%
# preprocessing
X_train_torch_mia, X_test_torch_mia, Y_train_torch_mia, Y_test_torch_mia, feature_names_mia = preprocess_data(merged_mia_df)

# %%
MIA_RF_model, MIA_metrics_RF = train_random_forest(X_train_torch_mia, X_test_torch_mia, Y_train_torch_mia, Y_test_torch_mia, feature_names_mia)

# %%
MIA_LSTM_model, MIA_metrics_LSTM = train_lstm(X_train_torch_mia, X_test_torch_mia, Y_train_torch_mia, Y_test_torch_mia)

# %%
MIA_RFLSTM_model, MIA_metrics_RFLSTM = train_rf_then_lstm(X_train_torch_mia, X_test_torch_mia, Y_train_torch_mia, Y_test_torch_mia, feature_names_mia)

# %% [markdown]
# ### LAX Models

# %%
# import dataset
merged_lax_df = pd.read_csv('data/complete/LAX_final_df.csv')

# %%
# preprocessing
X_train_torch_lax, X_test_torch_lax, Y_train_torch_lax, Y_test_torch_lax, feature_names_lax = preprocess_data(merged_lax_df)

# %%
LAX_RF_model, LAX_metrics_RF = train_random_forest(X_train_torch_lax, X_test_torch_lax, Y_train_torch_lax, Y_test_torch_lax, feature_names_lax)
# Out:
# c:\Users\mhair\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\mhair\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Training Set Metrics:
# Train Accuracy: 0.8446
# Train Precision: 0.7134
# Train Recall: 0.8446
# Train F1: 0.7735
#
# Test Set Metrics:
# Test Accuracy: 0.8231
# Test Precision: 0.6776
# Test Recall: 0.8231
# Test F1: 0.7433

# %%
LAX_LSTM_model, LAX_metrics_LSTM = train_lstm(X_train_torch_lax, X_test_torch_lax, Y_train_torch_lax, Y_test_torch_lax)
# Out:
# Epoch [10/100], Loss: 0.1969, Accuracy: 0.9408
# Epoch [20/100], Loss: 0.1931, Accuracy: 0.9417
# Epoch [30/100], Loss: 0.1913, Accuracy: 0.9423
# Epoch [40/100], Loss: 0.1902, Accuracy: 0.9428
# Epoch [50/100], Loss: 0.1895, Accuracy: 0.9430
# Epoch [60/100], Loss: 0.1888, Accuracy: 0.9430
# Epoch [70/100], Loss: 0.1883, Accuracy: 0.9432
# Epoch [80/100], Loss: 0.1878, Accuracy: 0.9433
# Epoch [90/100], Loss: 0.1875, Accuracy: 0.9436
# Epoch [100/100], Loss: 0.1874, Accuracy: 0.9438
#
# Training Set Metrics:
# Accuracy: 0.9446
# Precision: 0.9400
# Recall: 0.9446
# F1-score: 0.9416
#
# Test Set Metrics:
# Accuracy: 0.9185
# Precision: 0.9108
# Recall: 0.9185
# F1-score: 0.9135

# %%
LAX_RFLSTM_model, LAX_metrics_RFLSTM = train_rf_then_lstm(X_train_torch_lax, X_test_torch_lax, Y_train_torch_lax, Y_test_torch_lax, feature_names_lax)
# Out:
# Epoch [10/100], Loss: 0.2104, Accuracy: 0.9405
# Epoch [20/100], Loss: 0.2072, Accuracy: 0.9414
# Epoch [30/100], Loss: 0.2057, Accuracy: 0.9417
# Epoch [40/100], Loss: 0.2050, Accuracy: 0.9418
# Epoch [50/100], Loss: 0.2044, Accuracy: 0.9420
# Epoch [60/100], Loss: 0.2039, Accuracy: 0.9420
# Epoch [70/100], Loss: 0.2036, Accuracy: 0.9421
# Epoch [80/100], Loss: 0.2033, Accuracy: 0.9422
# Epoch [90/100], Loss: 0.2031, Accuracy: 0.9422
# Epoch [100/100], Loss: 0.2029, Accuracy: 0.9422
#
# Training Set Metrics:
# Accuracy: 0.9422
# Precision: 0.9374
# Recall: 0.9422
# F1-score: 0.9388
#
# Test Set Metrics:
# Accuracy: 0.9199
# Precision: 0.9128
# Recall: 0.9199
# F1-score: 0.9147

# %% [markdown]
# ### EWR Models

# %%
# import dataset
merged_ewr_df = pd.read_csv('data/complete/EWR_final_df.csv')

# %%
# preprocessing
X_train_torch_ewr, X_test_torch_ewr, Y_train_torch_ewr, Y_test_torch_ewr, feature_names_ewr = preprocess_data(merged_ewr_df)

# %%
EWR_RF_model, EWR_metrics_RF = train_random_forest(X_train_torch_ewr, X_test_torch_ewr, Y_train_torch_ewr, Y_test_torch_ewr, feature_names_ewr)

# %%
EWR_LSTM_model, EWR_metrics_LSTM = train_lstm(X_train_torch_ewr, X_test_torch_ewr, Y_train_torch_ewr, Y_test_torch_ewr)

# %%
EWR_RFLSTM_model, EWR_metrics_RFLSTM = train_rf_then_lstm(X_train_torch_ewr, X_test_torch_ewr, Y_train_torch_ewr, Y_test_torch_ewr, feature_names_ewr)

# %% [markdown]
# ### ORD Models

# %%
# import dataset
merged_ord_df = pd.read_csv('data/complete/ORD_final_df.csv')

# %%
# preprocessing
X_train_torch_ord, X_test_torch_ord, Y_train_torch_ord, Y_test_torch_ord, feature_names_ord = preprocess_data(merged_ord_df)

# %%
ORD_RF_model, ORD_metrics_RF = train_random_forest(X_train_torch_ord, X_test_torch_ord, Y_train_torch_ord, Y_test_torch_ord, feature_names_ord)
# Out:
# c:\Users\mhair\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\mhair\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Training Set Metrics:
# Train Accuracy: 0.7931
# Train Precision: 0.6290
# Train Recall: 0.7931
# Train F1: 0.7016
#
# Test Set Metrics:
# Test Accuracy: 0.8258
# Test Precision: 0.6819
# Test Recall: 0.8258
# Test F1: 0.7470

# %%
ORD_LSTM_model, ORD_metrics_LSTM = train_lstm(X_train_torch_ord, X_test_torch_ord, Y_train_torch_ord, Y_test_torch_ord)

# %%
ORD_RFLSTM_model, ORD_metrics_RFLSTM = train_rf_then_lstm(X_train_torch_ord, X_test_torch_ord, Y_train_torch_ord, Y_test_torch_ord, feature_names_ord)
# Out:
# Epoch [10/100], Loss: 0.3278, Accuracy: 0.9063
# Epoch [20/100], Loss: 0.3248, Accuracy: 0.9070
# Epoch [30/100], Loss: 0.3235, Accuracy: 0.9072
# Epoch [40/100], Loss: 0.3228, Accuracy: 0.9073
# Epoch [50/100], Loss: 0.3221, Accuracy: 0.9075
# Epoch [60/100], Loss: 0.3217, Accuracy: 0.9075
# Epoch [70/100], Loss: 0.3214, Accuracy: 0.9076
# Epoch [80/100], Loss: 0.3211, Accuracy: 0.9076
# Epoch [90/100], Loss: 0.3209, Accuracy: 0.9076
# Epoch [100/100], Loss: 0.3206, Accuracy: 0.9076
#
# Training Set Metrics:
# Accuracy: 0.9051
# Precision: 0.8944
# Recall: 0.9051
# F1-score: 0.8984
#
# Test Set Metrics:
# Accuracy: 0.9180
# Precision: 0.9084
# Recall: 0.9180
# F1-score: 0.9121

# %% [markdown]
# ### Benchmark models on all aiports - crossvalidation

# %%
# Airport data
airports = ['JFK', 'EWR', 'LAX', 'MIA', 'ORD']
airport_data_dict = {
    'JFK': merged_jfk_df,
    'EWR': merged_ewr_df,
    'LAX': merged_lax_df,
    'MIA': merged_mia_df,
    'ORD': merged_ord_df
}

# %%
# Training RF model
rf_metrics = crossvalidation_training(train_random_forest, airports, airport_data_dict)
# Out:
# fold: 1
# /opt/conda/envs/dbba_env/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# data preprocessed
# /opt/conda/envs/dbba_env/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/envs/dbba_env/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Training Set Metrics:
# Train Accuracy: 0.8154
# Train Precision: 0.6649
# Train Recall: 0.8154
# Train F1: 0.7325
#
# Test Set Metrics:
# Test Accuracy: 0.8353
# Test Precision: 0.6977
# Test Recall: 0.8353
# Test F1: 0.7604
# fold: 2
# /opt/conda/envs/dbba_env/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# data preprocessed
# /opt/conda/envs/dbba_env/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/envs/dbba_env/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Training Set Metrics:
# Train Accuracy: 0.8178
# Train Precision: 0.6689
# Train Recall: 0.8178
# Train F1: 0.7359
#
# Test Set Metrics:
# Test Accuracy: 0.8265
# Test Precision: 0.6831
# Test Recall: 0.8265
# Test F1: 0.7480
# fold: 3
# /opt/conda/envs/dbba_env/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# data preprocessed
# /opt/conda/envs/dbba_env/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/envs/dbba_env/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Training Set Metrics:
# Train Accuracy: 0.8099
# Train Precision: 0.6560
# Train Recall: 0.8099
# Train F1: 0.7248
#
# Test Set Metrics:
# Test Accuracy: 0.8615
# Test Precision: 0.7422
# Test Recall: 0.8615
# Test F1: 0.7974
# fold: 4
# /opt/conda/envs/dbba_env/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# data preprocessed
# /opt/conda/envs/dbba_env/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/envs/dbba_env/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Training Set Metrics:
# Train Accuracy: 0.8293
# Train Precision: 0.6877
# Train Recall: 0.8293
# Train F1: 0.7519
#
# Test Set Metrics:
# Test Accuracy: 0.7763
# Test Precision: 0.6026
# Test Recall: 0.7763
# Test F1: 0.6785
# fold: 5
# /opt/conda/envs/dbba_env/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# data preprocessed
# /opt/conda/envs/dbba_env/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/envs/dbba_env/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Training Set Metrics:
# Train Accuracy: 0.8250
# Train Precision: 0.6807
# Train Recall: 0.8250
# Train F1: 0.7459
#
# Test Set Metrics:
# Test Accuracy: 0.8021
# Test Precision: 0.6434
# Test Recall: 0.8021
# Test F1: 0.7140

# %%
# Training LSTM model
lstm_metrics = crossvalidation_training(train_lstm, airports, airport_data_dict)
# Out:
# fold: 1
# /opt/conda/envs/dbba_env/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# data preprocessed
# Epoch [10/100], Loss: 0.2571, Accuracy: 0.9185
# Epoch [20/100], Loss: 0.1969, Accuracy: 0.9382
# Epoch [30/100], Loss: 0.1580, Accuracy: 0.9519
# Epoch [40/100], Loss: 0.1306, Accuracy: 0.9614
# Epoch [50/100], Loss: 0.1104, Accuracy: 0.9674
# Epoch [60/100], Loss: 0.0952, Accuracy: 0.9720
# Epoch [70/100], Loss: 0.0830, Accuracy: 0.9752
# Epoch [80/100], Loss: 0.0734, Accuracy: 0.9787
# Epoch [90/100], Loss: 0.0660, Accuracy: 0.9805
# Epoch [100/100], Loss: 0.0594, Accuracy: 0.9828
#
# Training Set Metrics:
# Accuracy: 0.9863
# Precision: 0.9861
# Recall: 0.9863
# F1-score: 0.9861
#
# Test Set Metrics:
# Accuracy: 0.8613
# Precision: 0.8559
# Recall: 0.8613
# F1-score: 0.8572
# fold: 2
# /opt/conda/envs/dbba_env/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# data preprocessed
# Epoch [10/100], Loss: 0.2718, Accuracy: 0.9164
# Epoch [20/100], Loss: 0.2133, Accuracy: 0.9347
# Epoch [30/100], Loss: 0.1737, Accuracy: 0.9468
# Epoch [40/100], Loss: 0.1460, Accuracy: 0.9561
# Epoch [50/100], Loss: 0.1255, Accuracy: 0.9620
# Epoch [60/100], Loss: 0.1102, Accuracy: 0.9668
# Epoch [70/100], Loss: 0.0981, Accuracy: 0.9707
# Epoch [80/100], Loss: 0.0881, Accuracy: 0.9734
# Epoch [90/100], Loss: 0.0799, Accuracy: 0.9760
# Epoch [100/100], Loss: 0.0725, Accuracy: 0.9789
#
# Training Set Metrics:
# Accuracy: 0.9821
# Precision: 0.9818
# Recall: 0.9821
# F1-score: 0.9818
#
# Test Set Metrics:
# Accuracy: 0.8729
# Precision: 0.8671
# Recall: 0.8729
# F1-score: 0.8696
# fold: 3
# /opt/conda/envs/dbba_env/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# data preprocessed
# Epoch [10/100], Loss: 0.2839, Accuracy: 0.9114
# Epoch [20/100], Loss: 0.2242, Accuracy: 0.9294
# Epoch [30/100], Loss: 0.1848, Accuracy: 0.9416
# Epoch [40/100], Loss: 0.1571, Accuracy: 0.9513
# Epoch [50/100], Loss: 0.1372, Accuracy: 0.9584
# Epoch [60/100], Loss: 0.1213, Accuracy: 0.9630
# Epoch [70/100], Loss: 0.1084, Accuracy: 0.9674
# Epoch [80/100], Loss: 0.0981, Accuracy: 0.9707
# Epoch [90/100], Loss: 0.0897, Accuracy: 0.9739
# Epoch [100/100], Loss: 0.0822, Accuracy: 0.9750
#
# Training Set Metrics:
# Accuracy: 0.9817
# Precision: 0.9815
# Recall: 0.9817
# F1-score: 0.9815
#
# Test Set Metrics:
# Accuracy: 0.8614
# Precision: 0.8646
# Recall: 0.8614
# F1-score: 0.8620
# fold: 4
# /opt/conda/envs/dbba_env/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# data preprocessed
# Epoch [10/100], Loss: 0.2601, Accuracy: 0.9197
# Epoch [20/100], Loss: 0.1982, Accuracy: 0.9384
# Epoch [30/100], Loss: 0.1564, Accuracy: 0.9525
# Epoch [40/100], Loss: 0.1280, Accuracy: 0.9617
# Epoch [50/100], Loss: 0.1067, Accuracy: 0.9681
# Epoch [60/100], Loss: 0.0910, Accuracy: 0.9733
# Epoch [70/100], Loss: 0.0789, Accuracy: 0.9770
# Epoch [80/100], Loss: 0.0699, Accuracy: 0.9797
# Epoch [90/100], Loss: 0.0621, Accuracy: 0.9819
# Epoch [100/100], Loss: 0.0561, Accuracy: 0.9837
#
# Training Set Metrics:
# Accuracy: 0.9882
# Precision: 0.9880
# Recall: 0.9882
# F1-score: 0.9881
#
# Test Set Metrics:
# Accuracy: 0.8186
# Precision: 0.8232
# Recall: 0.8186
# F1-score: 0.8189
# fold: 5
# /opt/conda/envs/dbba_env/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# data preprocessed
# Epoch [10/100], Loss: 0.2635, Accuracy: 0.9192
# Epoch [20/100], Loss: 0.2096, Accuracy: 0.9352
# Epoch [30/100], Loss: 0.1729, Accuracy: 0.9470
# Epoch [40/100], Loss: 0.1465, Accuracy: 0.9554
# Epoch [50/100], Loss: 0.1271, Accuracy: 0.9618
# Epoch [60/100], Loss: 0.1116, Accuracy: 0.9671
# Epoch [70/100], Loss: 0.1003, Accuracy: 0.9704
# Epoch [80/100], Loss: 0.0902, Accuracy: 0.9736
# Epoch [90/100], Loss: 0.0821, Accuracy: 0.9762
# Epoch [100/100], Loss: 0.0753, Accuracy: 0.9785
#
# Training Set Metrics:
# Accuracy: 0.9817
# Precision: 0.9813
# Recall: 0.9817
# F1-score: 0.9814
#
# Test Set Metrics:
# Accuracy: 0.7472
# Precision: 0.8258
# Recall: 0.7472
# F1-score: 0.7805
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 3
#       1 # Training LSTM model
#       2 lstm_metrics = crossvalidation_training(train_lstm, airports, airport_data_dict)
# ----> 3 lstm_avg_metrics = metric_avgs(lstm_metrics)
#
# File ~/MLP_Project-1/cross_validation.py:48, in metric_avgs(val_metrics)
#      45 f1s = []
#      47 for dict in val_metrics:
# ---> 48     accuracies.append(dict['test']['accuracy'])
#      49     precisions.append(dict['test']['precision'])
#      50     recalls.append(dict['test']['recall'])
#
# KeyError: 'test'

# %%
print(rf_metrics)
print(lstm_metrics)
print(ens)
# Out:
# [{'train_accuracy': 0.825022709576953, 'train_precision': 0.6806624713176973, 'train_recall': 0.825022709576953, 'train_f1': 0.7459221934564063, 'test_accuracy': 0.8021011360209108, 'test_precision': 0.6433662324060357, 'test_recall': 0.8021011360209108, 'test_f1': 0.7140178978263185}]
# [{'train_accuracy': 0.9816701271736309, 'train_precision': 0.9813307748140344, 'train_recall': 0.9816701271736309, 'train_f1': 0.9813510665926938, 'test_accuracy': 0.7471599477229315, 'test_precision': 0.825797869657827, 'test_recall': 0.7471599477229315, 'test_f1': 0.780507064545045}]

# %%
# Training Ensemble model
ensemble_metrics = crossvalidation_training(train_rf_then_lstm, airports, airport_data_dict)
ensemble_avg_metrics = metric_avgs(ensemble_metrics)

# %% [markdown]
# ### SHAP

# %%
# SHAP for LSTM

# Create the SHAP explainer
explainer = shap.DeepExplainer(JFK_LSTM_model, X_test_torch_jfk) 
shap_values = explainer.shap_values(X_test_torch_jfk) # This bit runs infinitely?


# Mean SHAP plot
# shap.summary_plot(shap_values, X_test_torch_jfk)
# Out:
# /opt/anaconda3/envs/mlp/lib/python3.9/site-packages/shap/explainers/_deep/deep_pytorch.py:243: UserWarning: unrecognized nn.Module: LSTM
#   warnings.warn(f'unrecognized nn.Module: {module_type}')

# %% [markdown]
# tutorial notes:
# - keep decision tree and random forest parameters the same (e.g. depth and min leafs)
# - try training with full set of features, and top 10
# - PCA? corrplots?
# - training and test not random - first 80%, last 20%
# - remove weather delay feature
#
# NEED TO DO SHAP ANALYSIS FOR EACH MODEL
#
# generalisation experiments:
# - train and test on all airports (80/20 split)
# - train on full JFK airport, test on other airports
#
#
# not sure if the ensemble model is implemented properly
